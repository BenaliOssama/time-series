# %%
import pandas as pd
import numpy as np

business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

market_data = pd.DataFrame(
    index=index,
    data=np.random.randn(len(index), 1),
    columns=['Price']
)

print(market_data.head(10))
# Out:
#                       Price
# Date       Ticker
# 2021-01-01 AAPL   -0.698397
#            FB     -0.605145
#            GE     -0.453921
#            AMZN    1.112618
#            DAI    -1.630167
# 2021-01-04 AAPL   -0.046723
#            FB      1.706507
#            GE      0.197974
#            AMZN   -0.780370
#            DAI     0.758343

# %%
pivoted = market_data.pivot_table(values='Price', index='Date', columns='Ticker')
print(pivoted.head())
# Out:
# Ticker          AAPL      AMZN       DAI        FB        GE
# Date
# 2021-01-01 -0.698397  1.112618 -1.630167 -0.605145 -0.453921
# 2021-01-04 -0.046723 -0.780370  0.758343  1.706507  0.197974
# 2021-01-05  1.096044  1.350536  0.333049 -1.117248  0.730742
# 2021-01-06  0.856232 -0.752644  0.555582 -1.576803  1.077606
# 2021-01-07 -0.132583 -0.711064  0.316191 -0.919096  1.301100

# %%
returns = pivoted.pct_change()
print(returns.head())
# Out:
# Ticker           AAPL      AMZN       DAI        FB        GE
# Date
# 2021-01-01        NaN       NaN       NaN       NaN       NaN
# 2021-01-04  -0.933100 -1.701382 -1.465193 -3.819998 -1.436141
# 2021-01-05 -24.458505 -2.730635 -0.560820 -1.654699  2.691106
# 2021-01-06  -0.218798 -1.557293  0.668169  0.411328  0.474674
# 2021-01-07  -1.154844 -0.055245 -0.430884 -0.417114  0.207399

# %%
print(returns.shape)
# Out:
# (261, 5)
